# %% [markdown]
# # Text visualisations using wordcloud library by Sunitha Mekala

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
pip install wordcloud
# Out:
# ...
#    ---------------------------------------- 0.0/301.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.2 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/301.2 kB 495.5 kB/s eta 0:00:01
#    ------- ------------------------------- 61.4/301.2 kB 469.7 kB/s eta 0:00:01
#    --------------------- ------------------ 163.8/301.2 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  297.0/301.2 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 301.2/301.2 kB 1.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Create a list of word

text=("Python Python Python Matplotlib Matplotlib Seaborn Network Plot Violin Chart Pandas Datascience Wordcloud Spider Radar Parrallel Alpha Color Brewer Density Scatter Barplot Barplot Boxplot Violinplot Treemap Stacked Area Chart Chart Visualization Dataviz Donut Pie Time-Series Wordcloud Wordcloud Sankey Bubble")

# %%
text
# Out:
# 'Python Python Python Matplotlib Matplotlib Seaborn Network Plot Violin Chart Pandas Datascience Wordcloud Spider Radar Parrallel Alpha Color Brewer Density Scatter Barplot Barplot Boxplot Violinplot Treemap Stacked Area Chart Chart Visualization Dataviz Donut Pie Time-Series Wordcloud Wordcloud Sankey Bubble'

# %%
#Create the wordcloud object
wordcloud = WordCloud(width=420, height=200, margin=2, background_color='black', colormap='Accent',mode = 'RGBA').generate(text)

# %%
#Display the generated image:
plt.imshow(wordcloud, interpolation='quadric')
plt.axis('off')
plt.margins(x=0,y=0)
plt.show()

# %%
text="""
Artificial intelligence is rapidly changing the way we live and work.
Machine learning algorithms can analyze vast amounts of data to uncover patterns.
Deep learning, a subset of machine learning, uses neural networks to mimic the human brain.
AI is transforming industries like healthcare, finance, and transportation.
In healthcare, AI helps diagnose diseases, analyze medical images, and recommend treatments.
AI is also being used in personalized medicine to tailor treatments to individual patients.
Self-driving cars rely on AI to make real-time decisions on the road.
In the financial sector, AI algorithms can predict market trends and optimize trading strategies.
AI-powered chatbots are revolutionizing customer service by providing instant support.
In retail, AI helps companies optimize their inventory and improve customer experiences.
Blockchain technology is gaining traction for its potential in secure and transparent transactions.
Cryptocurrency, powered by blockchain, is disrupting traditional financial systems.
Cloud computing enables businesses to store and process data remotely, improving scalability.
The Internet of Things (IoT) connects everyday devices, allowing them to share data and interact.
Cybersecurity is becoming more critical as the number of cyber threats continues to rise.
Augmented reality (AR) is enhancing how we interact with the digital world in real-time.
Virtual reality (VR) provides immersive experiences in gaming, education, and healthcare.
5G technology promises faster internet speeds and lower latency, enabling new innovations.
The rise of electric vehicles is reducing dependence on fossil fuels and lowering carbon emissions.
Sustainable energy sources like wind and solar power are crucial to fighting climate change.
Recycling and waste management technologies are evolving to reduce environmental impact.
Social media platforms have changed how we communicate, share information, and interact.
E-commerce continues to grow, with more consumers opting for online shopping experiences.
Digital transformation is reshaping businesses and industries across the globe.
Automation and robotics are revolutionizing manufacturing, making production more efficient.
Wearable devices like smartwatches help people monitor their health and fitness in real time.
The gig economy is changing the way people work, with more people opting for freelancing.
AI in education is enabling personalized learning and improving student outcomes.
The role of data science is expanding, as businesses leverage data to make better decisions.
Data privacy concerns are becoming more pressing with the increasing amount of personal information online.
Sustainability is becoming a top priority for businesses aiming to reduce their environmental footprint.
"""

# %%
#Create the wordcloud object
wordcloud = WordCloud(width=420, height=200, margin=2, background_color='skyblue', colormap='Accent',mode = 'RGBA').generate(text)

# %%
#Display the generated image:
plt.imshow(wordcloud, interpolation='quadric')
plt.axis('off')
plt.margins(x=0,y=0)
plt.show()
